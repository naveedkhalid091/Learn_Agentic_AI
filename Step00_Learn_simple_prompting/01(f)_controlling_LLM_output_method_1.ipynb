# %% [markdown]
# <a href="https://colab.research.google.com/github/naveedkhalid091/Learn_Agentic_AI/blob/main/step00_hello_world/01(f)_controlling_LLM_output_method_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Controlling the output generated by the LLM:
#
# We as a developer can control the LLM output by setting the **temprature** and the **max_output_tokens** range.
#
# - **Temprature:** This parameter controls the creativity of the response, the temprature range would normally **from 0 to 1**. Bigger the number (i.e. 1) will make the LLM more creative and shorter range will make the LLM more specific (straightforward answer) & less creative.
# - **max_output_tokens:** This parameter set the LLM limit of the maximum number of tokens in a single prompt.

# %%
# !pip install -U -q "google-generativeai>=0.7.2"

# %%
import google.generativeai as genai

# %%
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model=genai.GenerativeModel(
    "gemini-2.0-flash-exp",
     generation_config=genai.GenerationConfig(
     temperature=0.7,
     max_output_tokens=10,
     )
)

# %%
response=model.generate_content("How is Imran Khan? write 50 lines for him ")

print(response.text)
# Out:
# Okay, here are 50 lines about Imran Khan, aiming to capture different facets of his complex and often

# %% [markdown]
# **Note:** Even I have requested to write 50 lines but LLM has stepped generating content after 22 tokens.

# %%
model=genai.GenerativeModel(
    "gemini-2.0-flash-exp",
     generation_config=genai.GenerationConfig(
     temperature=0.7,
     max_output_tokens=1000,
     )
)

# %%
response=model.generate_content("How is Imran Khan? write 50 lines for him ")

print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1491.59ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1238.73ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.0-flash-exp:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1189.06ms
# Okay, here are 50 lines about Imran Khan, aiming to capture different facets of his life and career. It's important to note that perspectives on him are diverse and often strongly held, so this tries to be comprehensive rather than purely celebratory or critical:
#
# 1. Imran Khan, a name synonymous with cricket legend.
# 2. A charismatic all-rounder, known for his fierce competitiveness.
# 3. Led Pakistan to victory in the 1992 Cricket World Cup, a national triumph.
# 4. A captain who inspired a generation of cricketers.
# ...
